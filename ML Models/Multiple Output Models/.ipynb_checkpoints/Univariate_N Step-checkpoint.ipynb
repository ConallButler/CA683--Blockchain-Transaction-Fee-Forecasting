# %%
import pandas as pd
import numpy as np
from numpy import array
from numpy import mean
from numpy import std
from keras.models import Sequential
from tensorflow.keras.layers import LSTM
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras.layers import TimeDistributed
from sklearn.preprocessing import MinMaxScaler

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out, step_interval):
    X, y = list(), list()
    example_count = int((len(sequence)/step_interval))
    for i in range(example_count):
        # find the end of this pattern
        end_ix = (i*step_interval) + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the sequence
        if out_end_ix > len(sequence):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[(i*step_interval):end_ix], sequence[end_ix:out_end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
resample_rate = '5T'
start_date='2021-11-26 00:00:00'
end_date='2021-12-26 23:55:00' 
inputs = ['min_gas_price']
#No of timesteps behind to forecast on, no of timesteps to forecast ahead
n_steps_in = 2016
n_steps_out = 5
#How many timesteps between start of training examples
step_interval = 1

# %% [markdown]
# Load data, datetime to index, downsample with left edge label, convert wei to gwei

# %%
#Load data as float, datetime to index
data = pd.read_csv (r'C:\Users\conal\Desktop\MCM\Practicum\data\min,max,average gas 11-26 to 01-26 QUERY 2.csv', header=0)
data['block_timestamp'] = pd.to_datetime(data['block_timestamp'], format = '%Y-%m-%d %H:%M:%S UTC')
data = data.set_index('block_timestamp')
data = data.squeeze()
data = data.astype('float')

#Resample with left edge label i.e min 1-5 mean labelled as min1
data = data.resample(resample_rate).mean()
data
#Convert to gwei
data = data.apply(lambda x: x/1000000000)
data =data[inputs]

#Filter inputs, MinMax scale
data =data[inputs]
scaler = MinMaxScaler()
data[inputs] = scaler.fit_transform(data[inputs])
    

#Creat input:output examples
data = data[start_date:end_date].to_numpy()
X, y = split_sequence(data, n_steps_in, n_steps_out, step_interval)
y = y[:, :, :1]
X_train, X_val = np.split(X, [int(0.7 * len(X))])
#we are only lookign to forecast the min gas price
y_train, y_val = np.split(y, [int(0.7 * len(X))])

# %%
#Reshape to 3D for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], len(inputs)))
y_train =y_train.reshape((y_train.shape[0], y_train.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], len(inputs)))
y_val = y_val.reshape((y_val.shape[0], y_val.shape[1], 1))

# %%
# define model
model = Sequential()
model.add(LSTM(1024, activation='tanh', input_shape=(n_steps_in, len(inputs))))
model.add(Dense(n_steps_out))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 152/152 [==============================] - 78s 441ms/step - loss: 0.0010
# Epoch 2/10
# 152/152 [==============================] - 67s 439ms/step - loss: 9.1667e-04
# Epoch 3/10
# 152/152 [==============================] - 88s 579ms/step - loss: 8.6993e-04
# Epoch 4/10
# 152/152 [==============================] - 94s 617ms/step - loss: 8.4296e-04
# Epoch 5/10
# 152/152 [==============================] - 92s 607ms/step - loss: 8.3080e-04
# Epoch 6/10
# 152/152 [==============================] - 89s 587ms/step - loss: 8.1618e-04
# Epoch 7/10
# 152/152 [==============================] - 94s 619ms/step - loss: 8.1329e-04
# Epoch 8/10
# 152/152 [==============================] - 90s 589ms/step - loss: 8.0063e-04
# Epoch 9/10
# 152/152 [==============================] - 91s 602ms/step - loss: 8.1715e-04
# Epoch 10/10
# 152/152 [==============================] - 94s 617ms/step - loss: 8.0782e-04

# %%
model.save('Multivariate_1block_outliers')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: testLSTM4\assets
# INFO:tensorflow:Assets written to: testLSTM4\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000014E9FE3E4F0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
yhat = model.predict(X_val, verbose=1)
# Out:
# 65/65 [==============================] - 15s 220ms/step

# %% [markdown]
# ## Lets try without limiting outliers

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler

# %%
yhat = model.predict(X_val, verbose=1)

# %%
#Minmax scaler has been fit with 2d data, 
Evaluated_lag = 4

pred_descaled= (scaler.inverse_transform(array([yhat,]*len(inputs)).transpose()[Evaluated_lag]))[:, :1]
groud_truth_descaled= (scaler.inverse_transform(array([y_val,]*len(inputs)).transpose()[0][Evaluated_lag ]))[ :, :1]


f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey=True)
f.set_figwidth(20)
f.set_figheight(15)
ax1.plot(pred_descaled)
ax1.title.set_text('Gas Price Prediction')
ax2.plot(groud_truth_descaled)
ax2.title.set_text('Gas Price Actual')


ax3.title.set_text('Overlayed')
ax3.plot(groud_truth_descaled, color='blue',label='Predicted '+' Gas Price')
ax3.plot(pred_descaled, color='red',label='real '+' Gas Price')



print('RMSE ' + str(mean_squared_error(groud_truth_descaled, pred_descaled, squared=False)))
print('MAE ' + str(mean_absolute_error(groud_truth_descaled, pred_descaled)))
print('MAPE ' + str(mean_absolute_percentage_error(groud_truth_descaled, pred_descaled)))
print('R^2 ' + str(r2_score(groud_truth_descaled, pred_descaled)))
# Out:
# RMSE 18.984370360377444
# MAE 11.15907695285678
# MAPE 0.1454322002034732
# R^2 0.389374484151355

# %%
# Out:
# ['min_gas_price']

# %% [markdown]
# ## Lets add the 24 hour lag for min gas price

# %%
resample_rate = '5T'
start_date='2021-11-26 00:00:00'
end_date='2021-12-26 23:55:00' 
inputs = ['min_gas_price', 'max_gas_price', 'min_gas_price_24hr lag']
#No of timesteps behind to forecast on, no of timesteps to forecast ahead
n_steps_in = 2016
n_steps_out = 5
#How many timesteps between start of training examples
step_interval = 1

# %%
#Load data as float, datetime to index
data = pd.read_csv (r'C:\Users\conal\Desktop\MCM\Practicum\data\min,max,average gas 11-26 to 01-26 QUERY 2.csv', header=0)
data['block_timestamp'] = pd.to_datetime(data['block_timestamp'], format = '%Y-%m-%d %H:%M:%S UTC')
data = data.set_index('block_timestamp')
data = data.squeeze()
data = data.astype('float')

#Resample with left edge label i.e min 1-5 mean labelled as min1
data = data.resample(resample_rate).mean()

#Add 24hr lag for min gas price
data['min_gas_price_24hr lag'] = data['min_gas_price'].shift(288)
data = data[288:]

#Convert to gwei
data = data.apply(lambda x: x/1000000000)
data =data[inputs]

#Filter inputs
data =data[inputs]
scaler = MinMaxScaler()
data[inputs] = scaler.fit_transform(data[inputs])
    

#Creat input:output examples
data = data[start_date:end_date].to_numpy()
X, y = split_sequence(data, n_steps_in, n_steps_out, step_interval)
y = y[:, :, :1]
X_train, X_val = np.split(X, [int(0.7 * len(X))])
#we are only lookign to forecast the min gas price
y_train, y_val = np.split(y, [int(0.7 * len(X))])

# %%
#Reshape to 3D for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], len(inputs)))
y_train =y_train.reshape((y_train.shape[0], y_train.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], len(inputs)))
y_val = y_val.reshape((y_val.shape[0], y_val.shape[1], 1))

# %%
# define model
model = Sequential()
model.add(LSTM(1024, activation='tanh', input_shape=(n_steps_in, len(inputs))))
model.add(Dense(n_steps_out))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 145/145 [==============================] - 66s 440ms/step - loss: 0.0011
# Epoch 2/10
# 145/145 [==============================] - 65s 446ms/step - loss: 9.1669e-04
# Epoch 3/10
# 145/145 [==============================] - 64s 440ms/step - loss: 8.7567e-04
# Epoch 4/10
# 145/145 [==============================] - 66s 457ms/step - loss: 8.4167e-04
# Epoch 5/10
# 145/145 [==============================] - 64s 443ms/step - loss: 8.4588e-04
# Epoch 6/10
# 145/145 [==============================] - 64s 444ms/step - loss: 8.2534e-04
# Epoch 7/10
# 145/145 [==============================] - 69s 474ms/step - loss: 8.3009e-04
# Epoch 8/10
# 145/145 [==============================] - 66s 452ms/step - loss: 8.2828e-04
# Epoch 9/10
# 145/145 [==============================] - 64s 439ms/step - loss: 8.2196e-04
# Epoch 10/10
# 145/145 [==============================] - 63s 433ms/step - loss: 8.1631e-04

# %%
yhat2 = model.predict(X_val, verbose=1)
# Out:
# 63/63 [==============================] - 14s 220ms/step

# %%
#Minmax scaler has been fit with 2d data, 
Evaluated_lag = 4
 
pred_descaled= (scaler.inverse_transform(array([yhat2,]*len(inputs)).transpose()[Evaluated_lag]))[:, :1]
groud_truth_descaled= (scaler.inverse_transform(array([y_val,]*len(inputs)).transpose()[0][Evaluated_lag ]))[ :, :1]


f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey=True)
f.set_figwidth(20)
f.set_figheight(15)
ax1.plot(pred_descaled)
ax1.title.set_text('Gas Price Prediction')
ax2.plot(groud_truth_descaled)
ax2.title.set_text('Gas Price Actual')


ax3.title.set_text('Overlayed')
ax3.plot(groud_truth_descaled, color='blue',label='Predicted '+' Gas Price')
ax3.plot(pred_descaled, color='red',label='real '+' Gas Price')



print('RMSE ' + str(mean_squared_error(groud_truth_descaled, pred_descaled, squared=False)))
print('MAE ' + str(mean_absolute_error(groud_truth_descaled, pred_descaled)))
print('MAPE ' + str(mean_absolute_percentage_error(groud_truth_descaled, pred_descaled)))
print('R^2 ' + str(r2_score(groud_truth_descaled, pred_descaled)))
# Out:
# RMSE 21.2590859932424
# MAE 15.331846526145094
# MAPE 0.23248132473374414
# R^2 0.24914940564315735

# %% [markdown]
# Lets try train for another 10 epochs

# %%
model.fit(X_train, y_train, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 145/145 [==============================] - 63s 433ms/step - loss: 8.2661e-04
# Epoch 2/20
# 145/145 [==============================] - 63s 433ms/step - loss: 8.0990e-04
# Epoch 3/20
# 145/145 [==============================] - 63s 433ms/step - loss: 8.0944e-04
# Epoch 4/20
# 145/145 [==============================] - 63s 433ms/step - loss: 8.0573e-04
# Epoch 5/20
# 145/145 [==============================] - 63s 434ms/step - loss: 8.0944e-04
# Epoch 6/20
# 145/145 [==============================] - 63s 435ms/step - loss: 8.1259e-04
# Epoch 7/20
# 145/145 [==============================] - 63s 434ms/step - loss: 8.0821e-04
# Epoch 8/20
# 145/145 [==============================] - 63s 436ms/step - loss: 8.0924e-04
# Epoch 9/20
# 145/145 [==============================] - 63s 434ms/step - loss: 8.0081e-04
# Epoch 10/20
# 145/145 [==============================] - 63s 435ms/step - loss: 7.9896e-04
# Epoch 11/20
# 145/145 [==============================] - 68s 467ms/step - loss: 8.1616e-04
# Epoch 12/20
# 145/145 [==============================] - 66s 454ms/step - loss: 7.9301e-04
# Epoch 13/20
# 145/145 [==============================] - 67s 460ms/step - loss: 7.8680e-04
# Epoch 14/20
# 145/145 [==============================] - 67s 465ms/step - loss: 7.9273e-04
# Epoch 15/20
# 145/145 [==============================] - 66s 454ms/step - loss: 7.8675e-04
# Epoch 16/20
# 145/145 [==============================] - 64s 439ms/step - loss: 7.8280e-04
# Epoch 17/20
# 145/145 [==============================] - 64s 444ms/step - loss: 7.8319e-04
# Epoch 18/20
# 145/145 [==============================] - 68s 470ms/step - loss: 7.7180e-04
# Epoch 19/20
# 145/145 [==============================] - 68s 467ms/step - loss: 7.8456e-04
# Epoch 20/20
# 145/145 [==============================] - 65s 447ms/step - loss: 7.7293e-04

# %%
yhat3 = model.predict(X_val, verbose=1)
# Out:
# 63/63 [==============================] - 14s 220ms/step

# %%
#Minmax scaler has been fit with 2d data, 
Evaluated_lag = 4
 
pred_descaled= (scaler.inverse_transform(array([yhat3,]*len(inputs)).transpose()[Evaluated_lag]))[:, :1]
groud_truth_descaled= (scaler.inverse_transform(array([y_val,]*len(inputs)).transpose()[0][Evaluated_lag ]))[ :, :1]


f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey=True)
f.set_figwidth(20)
f.set_figheight(15)
ax1.plot(pred_descaled)
ax1.title.set_text('Gas Price Prediction')
ax2.plot(groud_truth_descaled)
ax2.title.set_text('Gas Price Actual')


ax3.title.set_text('Overlayed')
ax3.plot(groud_truth_descaled, color='blue',label='Predicted '+' Gas Price')
ax3.plot(pred_descaled, color='red',label='real '+' Gas Price')



print('RMSE ' + str(mean_squared_error(groud_truth_descaled, pred_descaled, squared=False)))
print('MAE ' + str(mean_absolute_error(groud_truth_descaled, pred_descaled)))
print('MAPE ' + str(mean_absolute_percentage_error(groud_truth_descaled, pred_descaled)))
print('R^2 ' + str(r2_score(groud_truth_descaled, pred_descaled)))
# Out:
# RMSE 27.682707387153677
# MAE 23.997343825092234
# MAPE 0.4072030455628568
# R^2 -0.27315557425854164

# %% [markdown]
# It looks like we have pretty major degredation of evaluation metrics in a multi-step output, overtraining is possible, and additional variable seem to have a negative effect on performance. A more complex model, with more input data may be a solution to this. Let see what happens when we reduce the complexity of the model

# %%
# define model
model = Sequential()
model.add(LSTM(512, activation='tanh', input_shape=(n_steps_in, len(inputs))))
model.add(Dense(n_steps_out))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 152/152 [==============================] - 26s 155ms/step - loss: 9.8433e-04
# Epoch 2/10
# 152/152 [==============================] - 23s 153ms/step - loss: 8.7057e-04
# Epoch 3/10
# 152/152 [==============================] - 23s 153ms/step - loss: 8.5229e-04
# Epoch 4/10
# 152/152 [==============================] - 23s 154ms/step - loss: 8.3653e-04
# Epoch 5/10
# 152/152 [==============================] - 23s 154ms/step - loss: 8.2142e-04
# Epoch 6/10
# 152/152 [==============================] - 23s 154ms/step - loss: 8.1354e-04
# Epoch 7/10
# 152/152 [==============================] - 24s 155ms/step - loss: 8.2217e-04
# Epoch 8/10
# 152/152 [==============================] - 24s 159ms/step - loss: 8.0995e-04
# Epoch 9/10
# 152/152 [==============================] - 24s 157ms/step - loss: 8.1333e-04
# Epoch 10/10
# 152/152 [==============================] - 24s 155ms/step - loss: 8.0263e-04

# %%
yhat4 = model.predict(X_val, verbose=1)
# Out:
# 65/65 [==============================] - 5s 66ms/step

# %%
#Minmax scaler has been fit with 2d data, 
Evaluated_lag = 4
 
pred_descaled= (scaler.inverse_transform(array([yhat4,]*len(inputs)).transpose()[Evaluated_lag]))[:, :1]
groud_truth_descaled= (scaler.inverse_transform(array([y_val,]*len(inputs)).transpose()[0][Evaluated_lag ]))[ :, :1]


f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey=True)
f.set_figwidth(20)
f.set_figheight(15)
ax1.plot(pred_descaled)
ax1.title.set_text('Gas Price Prediction')
ax2.plot(groud_truth_descaled)
ax2.title.set_text('Gas Price Actual')


ax3.title.set_text('Overlayed')
ax3.plot(groud_truth_descaled, color='blue',label='Predicted '+' Gas Price')
ax3.plot(pred_descaled, color='red',label='real '+' Gas Price')



print('RMSE ' + str(mean_squared_error(groud_truth_descaled, pred_descaled, squared=False)))
print('MAE ' + str(mean_absolute_error(groud_truth_descaled, pred_descaled)))
print('MAPE ' + str(mean_absolute_percentage_error(groud_truth_descaled, pred_descaled)))
print('R^2 ' + str(r2_score(groud_truth_descaled, pred_descaled)))
# Out:
# RMSE 18.05397562456752
# MAE 11.16741454546669
# MAPE 0.16043039531570352
# R^2 0.4477594971231952

# %% [markdown]
# Improvement with narrower LSTM layer

# %%
# define model
model = Sequential()
model.add(LSTM(256, activation='tanh', input_shape=(n_steps_in, len(inputs))))
model.add(Dense(n_steps_out))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 152/152 [==============================] - 19s 111ms/step - loss: 0.0011
# Epoch 2/10
# 152/152 [==============================] - 17s 111ms/step - loss: 9.0641e-04
# Epoch 3/10
# 152/152 [==============================] - 17s 112ms/step - loss: 8.5736e-04
# Epoch 4/10
# 152/152 [==============================] - 17s 112ms/step - loss: 8.4314e-04
# Epoch 5/10
# 152/152 [==============================] - 17s 113ms/step - loss: 8.3602e-04
# Epoch 6/10
# 152/152 [==============================] - 17s 112ms/step - loss: 8.1722e-04
# Epoch 7/10
# 152/152 [==============================] - 17s 111ms/step - loss: 8.0358e-04
# Epoch 8/10
# 152/152 [==============================] - 17s 113ms/step - loss: 8.0514e-04
# Epoch 9/10
# 152/152 [==============================] - 17s 112ms/step - loss: 8.0279e-04
# Epoch 10/10
# 152/152 [==============================] - 17s 114ms/step - loss: 7.9547e-04

# %%
yhat5 = model.predict(X_val, verbose=1)
# Out:
# 65/65 [==============================] - 4s 51ms/step

# %%
#Minmax scaler has been fit with 2d data, 
Evaluated_lag = 4
 
pred_descaled= (scaler.inverse_transform(array([yhat5,]*len(inputs)).transpose()[Evaluated_lag]))[:, :1]
groud_truth_descaled= (scaler.inverse_transform(array([y_val,]*len(inputs)).transpose()[0][Evaluated_lag ]))[ :, :1]


f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey=True)
f.set_figwidth(20)
f.set_figheight(15)
ax1.plot(pred_descaled)
ax1.title.set_text('Gas Price Prediction')
ax2.plot(groud_truth_descaled)
ax2.title.set_text('Gas Price Actual')


ax3.title.set_text('Overlayed')
ax3.plot(groud_truth_descaled, color='blue',label='Predicted '+' Gas Price')
ax3.plot(pred_descaled, color='red',label='real '+' Gas Price')



print('RMSE ' + str(mean_squared_error(groud_truth_descaled, pred_descaled, squared=False)))
print('MAE ' + str(mean_absolute_error(groud_truth_descaled, pred_descaled)))
print('MAPE ' + str(mean_absolute_percentage_error(groud_truth_descaled, pred_descaled)))
print('R^2 ' + str(r2_score(groud_truth_descaled, pred_descaled)))
# Out:
# RMSE 18.099472653039268
# MAE 10.914244421718498
# MAPE 0.15112904472753028
# R^2 0.4449726361027889

# %% [markdown]
# ## Lets try add an extra month of data

# %%
resample_rate = '5T'
start_date='2021-11-26 00:00:00'
end_date='2022-01-26 23:55:00' 
inputs = ['min_gas_price']
#No of timesteps behind to forecast on, no of timesteps to forecast ahead
n_steps_in = 2016
n_steps_out = 5
#How many timesteps between start of training examples
step_interval = 1

# %%
#Load data as float, datetime to index
data = pd.read_csv (r'C:\Users\conal\Desktop\MCM\Practicum\data\min,max,average gas 11-26 to 01-26 QUERY 2.csv', header=0)
data['block_timestamp'] = pd.to_datetime(data['block_timestamp'], format = '%Y-%m-%d %H:%M:%S UTC')
data = data.set_index('block_timestamp')
data = data.squeeze()
data = data.astype('float')

#Resample with left edge label i.e min 1-5 mean labelled as min1
data = data.resample(resample_rate).mean()

#Add 24hr lag for min gas price
data['min_gas_price_24hr lag'] = data['min_gas_price'].shift(288)
data = data[288:]

#Convert to gwei
data = data.apply(lambda x: x/1000000000)
data =data[inputs]

#Filter inputs
data =data[inputs]
scaler = MinMaxScaler()
data[inputs] = scaler.fit_transform(data[inputs])
    

#Creat input:output examples
data = data[start_date:end_date].to_numpy()
X, y = split_sequence(data, n_steps_in, n_steps_out, step_interval)
y = y[:, :, :1]
X_train, X_val = np.split(X, [int(0.7 * len(X))])
#we are only lookign to forecast the min gas price
y_train, y_val = np.split(y, [int(0.7 * len(X))])

# %%
#Reshape to 3D for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], len(inputs)))
y_train =y_train.reshape((y_train.shape[0], y_train.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], len(inputs)))
y_val = y_val.reshape((y_val.shape[0], y_val.shape[1], 1))

# %%
# define model
model = Sequential()
model.add(LSTM(256, activation='tanh', input_shape=(n_steps_in, len(inputs))))
model.add(Dense(n_steps_out))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 341/341 [==============================] - 41s 112ms/step - loss: 7.7906e-04
# Epoch 2/10
# 341/341 [==============================] - 39s 115ms/step - loss: 6.6850e-04
# Epoch 3/10
# 341/341 [==============================] - 39s 116ms/step - loss: 6.4340e-04
# Epoch 4/10
# 341/341 [==============================] - 40s 116ms/step - loss: 6.3360e-04
# Epoch 5/10
# 341/341 [==============================] - 39s 115ms/step - loss: 6.3517e-04
# Epoch 6/10
# 341/341 [==============================] - 39s 115ms/step - loss: 6.3139e-04
# Epoch 7/10
# 341/341 [==============================] - 39s 114ms/step - loss: 6.2869e-04
# Epoch 8/10
# 341/341 [==============================] - 39s 113ms/step - loss: 6.2004e-04
# Epoch 9/10
# 341/341 [==============================] - 39s 115ms/step - loss: 6.2300e-04
# Epoch 10/10
# 341/341 [==============================] - 39s 114ms/step - loss: 6.2392e-04

# %%
yhat6 = model.predict(X_val, verbose=1)
# Out:
# 146/146 [==============================] - 8s 49ms/step

# %%
#Minmax scaler has been fit with 2d data, 
Evaluated_lag = 4
 
pred_descaled= (scaler.inverse_transform(array([yhat6,]*len(inputs)).transpose()[Evaluated_lag]))[:, :1]
groud_truth_descaled= (scaler.inverse_transform(array([y_val,]*len(inputs)).transpose()[0][Evaluated_lag ]))[ :, :1]


f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey=True)
f.set_figwidth(20)
f.set_figheight(15)
ax1.plot(pred_descaled)
ax1.title.set_text('Gas Price Prediction')
ax2.plot(groud_truth_descaled)
ax2.title.set_text('Gas Price Actual')


ax3.title.set_text('Overlayed')
ax3.plot(groud_truth_descaled, color='blue',label='Predicted '+' Gas Price')
ax3.plot(pred_descaled, color='red',label='real '+' Gas Price')



print('RMSE ' + str(mean_squared_error(groud_truth_descaled, pred_descaled, squared=False)))
print('MAE ' + str(mean_absolute_error(groud_truth_descaled, pred_descaled)))
print('MAPE ' + str(mean_absolute_percentage_error(groud_truth_descaled, pred_descaled)))
print('R^2 ' + str(r2_score(groud_truth_descaled, pred_descaled)))
# Out:
# RMSE 53.28711281116926
# MAE 26.03397998583169
# MAPE 0.15680562979146337
# R^2 0.3261248490638897

# %%
Lets try two layers

# %%
# define model
model = Sequential()
model.add(LSTM(256, activation='tanh', input_shape=(n_steps_in, len(inputs)), return_sequences=True))
model.add(LSTM(256, activation='tanh'))
model.add(Dense(n_steps_out))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 341/341 [==============================] - 77s 212ms/step - loss: 8.0830e-04
# Epoch 2/10
# 341/341 [==============================] - 74s 217ms/step - loss: 6.8087e-04
# Epoch 3/10
# 341/341 [==============================] - 73s 213ms/step - loss: 6.4210e-04
# Epoch 4/10
# 341/341 [==============================] - 74s 218ms/step - loss: 6.3977e-04
# Epoch 5/10
# 341/341 [==============================] - 74s 217ms/step - loss: 6.3587e-04
# Epoch 6/10
# 341/341 [==============================] - 75s 219ms/step - loss: 6.3573e-04
# Epoch 7/10
# 341/341 [==============================] - 73s 213ms/step - loss: 6.3083e-04
# Epoch 8/10
# 341/341 [==============================] - 73s 213ms/step - loss: 6.2462e-04
# Epoch 9/10
# 341/341 [==============================] - 73s 213ms/step - loss: 6.2561e-04
# Epoch 10/10
# 341/341 [==============================] - 73s 213ms/step - loss: 6.1842e-04

# %%
yhat7 = model.predict(X_val, verbose=1)
# Out:
# 146/146 [==============================] - 15s 97ms/step

# %%
#Minmax scaler has been fit with 2d data, 
Evaluated_lag = 4
 
pred_descaled= (scaler.inverse_transform(array([yhat6,]*len(inputs)).transpose()[Evaluated_lag]))[:, :1]
groud_truth_descaled= (scaler.inverse_transform(array([y_val,]*len(inputs)).transpose()[0][Evaluated_lag ]))[ :, :1]


f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey=True)
f.set_figwidth(20)
f.set_figheight(15)
ax1.plot(pred_descaled)
ax1.title.set_text('Gas Price Prediction')
ax2.plot(groud_truth_descaled)
ax2.title.set_text('Gas Price Actual')


ax3.title.set_text('Overlayed')
ax3.plot(groud_truth_descaled, color='blue',label='Predicted '+' Gas Price')
ax3.plot(pred_descaled, color='red',label='real '+' Gas Price')



print('RMSE ' + str(mean_squared_error(groud_truth_descaled, pred_descaled, squared=False)))
print('MAE ' + str(mean_absolute_error(groud_truth_descaled, pred_descaled)))
print('MAPE ' + str(mean_absolute_percentage_error(groud_truth_descaled, pred_descaled)))
print('R^2 ' + str(r2_score(groud_truth_descaled, pred_descaled)))
# Out:
# RMSE 53.28711281116926
# MAE 26.03397998583169
# MAPE 0.15680562979146337
# R^2 0.3261248490638897
